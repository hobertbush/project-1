# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "Donuts": [1,4,3,2,7,6,9],
    "Days of the Week":['Mon.', 'Tues', 'Wens.', 'Thurs','Fri.','Sat.','Sun.']
})

# %%
chart = plt.plot(df['Days of the Week'], df['Donuts'])
